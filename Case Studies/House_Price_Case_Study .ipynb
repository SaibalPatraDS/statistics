# %%
import numpy as np 
import pandas as pd

from scipy import stats
from statsmodels.stats.weightstats import ztest

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option("display.max_row", 1000)
pd.set_option("display.max_column", 100)

# %%
data = pd.read_csv("Data/Housing.csv", index_col = 'Id')
data.head(10)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
# help(pd.read_csv)

# %%
data.shape
# Out:
# (1460, 80)

# %%
data.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %%
data.isnull().sum() > .50*data.shape[0]
# Out:
# MSSubClass       False
# MSZoning         False
# LotFrontage      False
# LotArea          False
# Street           False
# Alley             True
# LotShape         False
# LandContour      False
# Utilities        False
# LotConfig        False
# LandSlope        False
# Neighborhood     False
# Condition1       False
# Condition2       False
# BldgType         False
# HouseStyle       False
# OverallQual      False
# OverallCond      False
# YearBuilt        False
# YearRemodAdd     False
# RoofStyle        False
# RoofMatl         False
# Exterior1st      False
# Exterior2nd      False
# MasVnrType       False
# MasVnrArea       False
# ExterQual        False
# ExterCond        False
# Foundation       False
# BsmtQual         False
# BsmtCond         False
# BsmtExposure     False
# BsmtFinType1     False
# BsmtFinSF1       False
# BsmtFinType2     False
# BsmtFinSF2       False
# BsmtUnfSF        False
# TotalBsmtSF      False
# Heating          False
# HeatingQC        False
# ...

# %%
## basic plotting

sns.displot(data['SalePrice'])
plt.show()

# %%
## skewness and kurtosis value of SalePrice Column

data['SalePrice'].skew(), data['SalePrice'].kurt()
# Out:
# (1.8828757597682129, 6.536281860064529)

# %% [markdown]
# ### Kurtosis

# %% [raw]
# “higher kurtosis means more of the variance is the result of infrequent extreme deviations, as opposed to frequent modestly sized deviations.”

# %% [raw]
# 1 . A normal distribution has kurtosis exactly 3 (excess kurtosis exactly 0). Any distribution with kurtosis ≈3 (excess ≈0) is called mesokurtic.
# 2 . A distribution with kurtosis <3 (excess kurtosis <0) is called platykurtic. Compared to a normal distribution, its tails are shorter and thinner, and often its central peak is lower and broader.
# 3 . A distribution with kurtosis >3 (excess kurtosis >0) is called leptokurtic. Compared to a normal distribution, its tails are longer and fatter, and often its central peak is higher and sharper.
#
# Excess kurtosis = kurtosis - 3

# %% [markdown]
# ### Skewness

# %% [raw]
# The critical value of Zg1 is approximately 2. (This is a two-tailed test of skewness ≠ 0 at roughly the 0.05 significance level.)
#
# 1. If Zg1 < −2, the population is very likely skewed negatively (though you don’t know by how much).
# 2. If Zg1 is between −2 and +2, you can’t reach any conclusion about the skewness of the population: it might be symmetric, or it might be skewed in either direction.
# 3. If Zg1 > 2, the population is very likely skewed positively (though you don’t know by how much).

# %% [markdown]
# ### Statistical Analysis of `SalePrice`

# %%
##take a sample of size 500

np.random.seed(42)

sample_price = np.random.choice(data['SalePrice'], 500)
sample_price.mean(), data['SalePrice'].mean() #population mean
# Out:
# (180091.214, 180921.19589041095)

# %% [markdown]
# ### Statistical Analysis of `Neighborhood `

# %%
data['Neighborhood'].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
## test whether house prices in neighborhood of a particular places is same or not

# different sample so will be applying ztest

## importing packages
from statsmodels.stats.weightstats import ztest

tstat, pvalue = ztest(x1 = data[data['Neighborhood'] == 'Edwards']['SalePrice'], value = data['SalePrice'].mean())
tstat, pvalue
# Out:
# (-12.196987594087203, 3.2253680352007412e-34)

# %%
data[data['Neighborhood'] == 'Edwards']['SalePrice'].mean(), data['SalePrice'].mean()
# Out:
# (128219.7, 180921.19589041095)

# %%
help(ztest)
# Out:
# Help on function ztest in module statsmodels.stats.weightstats:
#
# ztest(x1, x2=None, value=0, alternative='two-sided', usevar='pooled', ddof=1.0)
#     test for mean based on normal distribution, one or two samples
#
#     In the case of two samples, the samples are assumed to be independent.
#
#     Parameters
#     ----------
#     x1 : array_like, 1-D or 2-D
#         first of the two independent samples
#     x2 : array_like, 1-D or 2-D
#         second of the two independent samples
#     value : float
#         In the one sample case, value is the mean of x1 under the Null
#         hypothesis.
#         In the two sample case, value is the difference between mean of x1 and
#         mean of x2 under the Null hypothesis. The test statistic is
#         `x1_mean - x2_mean - value`.
#     alternative : str
#         The alternative hypothesis, H1, has to be one of the following
#
#            'two-sided': H1: difference in means not equal to value (default)
# ...

# %% [markdown]
# **Conclusion**
#
# p-value is quite low, that's **we can not to reject NULL Hypothesis** that **the particular Neighbourhood SalePrice is different that of the whole population**.

# %%
## same type of ztest for different Neighbourhood

from statsmodels.stats.weightstats import ztest

tstat, pvalue = ztest(x1 = data[data['Neighborhood'] == 'CollgCr']['SalePrice'], value = data['SalePrice'].mean())
tstat, pvalue
# Out:
# (4.0610447181525355, 4.8853612013673004e-05)

# %% [markdown]
# **Conclusion**
#
# p-value is quite low, that's **we can not to reject NULL Hypothesis** that **the particular Neighbourhood SalePrice is different that of the whole population**.

# %% [markdown]
# #### 1 . What is minimum value I have to invest to get a house in a particular City? (with 95% confidence)

# %% [markdown]
# Hint -
#
# We will be dealing with saleprice of a particular city not the whole poplulation, so we can apply Z-score.

# %%
## z_score = (x - mean)/std

mean_OldTown_saleprice = data[data['Neighborhood'] == 'OldTown']['SalePrice'].mean()
stddev_OldTown_saleprice =  data[data['Neighborhood'] == 'OldTown']['SalePrice'].std()
sample_OldTown = data[data['Neighborhood'] == 'OldTown']['SalePrice'].count()

mean_OldTown_saleprice,stddev_OldTown_saleprice, sample_OldTown
# Out:
# (128225.30088495575, 52650.58318492048, 113)

# %%
confidence = 0.95
p_tail = (1-confidence)/2

z_score = stats.norm.ppf([p_tail, 1-p_tail])[1]
z_score
# Out:
# 1.959963984540054

# %%
#Calculating the upper limit of investment(considering mean error)
upper_limit = z_score * stddev_OldTown_saleprice + mean_OldTown_saleprice
lower_limit = -z_score * stddev_OldTown_saleprice + mean_OldTown_saleprice

# %%
upper_limit, lower_limit
# Out:
# (231418.54769243006, 25032.054077481444)
